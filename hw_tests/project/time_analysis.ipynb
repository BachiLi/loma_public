# %%
openMpi = [0.579362154006958,0.3756089210510254, 0.4942457675933838, 0.38225388526916504, 0.4099760055541992,0.41822123527526855,0.47961997985839844,1.1974852085113525,8.722813129425049 ]
Loma = [9.489059448242188e-05,6.008148193359375e-05, 6.29425048828125e-05, 0.0003058910369873047, 0.002768993377685547, 0.03461003303527832,0.29762721061706543, 2.805612087249756,80.92804718017578 ]

# %%
import matplotlib.pyplot as plt

# Dummy data

# Iterations (x-axis)
iterations = list(range(1, len(openMpi) + 1))

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(iterations, openMpi, marker='o', label='openMpi')
plt.plot(iterations, Loma, marker='x', label='loma')

# Labeling the axes
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')

# Title and legend
plt.title('Performance over Iterations')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
